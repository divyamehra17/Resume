# %% [markdown]
# <a href="https://colab.research.google.com/github/divyamehra17/Resume/blob/main/icbms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cleaning and preparing the data for model training

# %%
#importing the libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#importing the dataset
df=pd.read_csv('/home/vistan-lap-10/Documents/icbms dataset/most imp dataset/Skeleton-Based-Human-Action-Recognition-master/data/skeleton_filtered.csv',encoding='latin-1')
df.head()
# Out:
#      nose_x    nose_y    neck_x  neck_y  ...    REar_y    LEar_x    LEar_y  class
# 0  0.643519  0.157609  0.634259    0.25  ...  0.157609  0.666667  0.152174   kick
# 1  0.643519  0.157609  0.634259    0.25  ...  0.157609  0.666667  0.152174   kick
# 2  0.643519  0.157609  0.638889    0.25  ...  0.157609  0.671296  0.152174   kick
# 3  0.643519  0.157609  0.638889    0.25  ...  0.157609  0.666667  0.152174   kick
# 4  0.643519  0.157609  0.638889    0.25  ...  0.157609  0.666667  0.152174   kick
#
# [5 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['nose_x', 'nose_y', 'neck_x', 'neck_y', 'Rshoulder_x', 'Rshoulder_y',
#        'Relbow_x', 'Relbow_y', 'Rwrist_x', 'RWrist_y', 'LShoulder_x',
#        'LShoulder_y', 'LElbow_x', 'LElbow_y', 'LWrist_x', 'LWrist_y', 'RHip_x',
#        'RHip_y', 'RKnee_x', 'RKnee_y', 'RAnkle_x', 'RAnkle_y', 'LHip_x',
#        'LHip_y', 'LKnee_x', 'LKnee_y', 'LAnkle_x', 'LAnkle_y', 'REye_x',
#        'REye_y', 'LEye_x', 'LEye_y', 'REar_x', 'REar_y', 'LEar_x', 'LEar_y',
#        'class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1584 entries, 0 to 1583
# Data columns (total 37 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   nose_x       1584 non-null   float64
#  1   nose_y       1584 non-null   float64
#  2   neck_x       1584 non-null   float64
#  3   neck_y       1584 non-null   float64
#  4   Rshoulder_x  1584 non-null   float64
#  5   Rshoulder_y  1584 non-null   float64
#  6   Relbow_x     1584 non-null   float64
#  7   Relbow_y     1584 non-null   float64
#  8   Rwrist_x     1584 non-null   float64
#  9   RWrist_y     1583 non-null   float64
#  10  LShoulder_x  1583 non-null   float64
#  11  LShoulder_y  1583 non-null   float64
#  12  LElbow_x     1583 non-null   float64
#  13  LElbow_y     1583 non-null   float64
#  14  LWrist_x     1583 non-null   float64
#  15  LWrist_y     1583 non-null   float64
#  16  RHip_x       1583 non-null   float64
#  17  RHip_y       1583 non-null   float64
# ...

# %%
df.describe()
# Out:
#             nose_x       nose_y  ...       LEar_x       LEar_y
# count  1584.000000  1584.000000  ...  1583.000000  1583.000000
# mean      0.586645     0.312263  ...     0.484342     0.238609
# std       0.052490     0.140211  ...     0.250453     0.172137
# min       0.453704     0.125000  ...     0.000000     0.000000
# 25%       0.550926     0.163043  ...     0.537037     0.141304
# 50%       0.578704     0.336957  ...     0.597222     0.163043
# 75%       0.620370     0.467391  ...     0.629630     0.440217
# max       0.731481     0.548913  ...     0.745370     0.516304
#
# [8 rows x 36 columns]

# %% [markdown]
# In Data Analysis What All Things We Do
#
#     Missing Values
#     Explore About the Numerical Variables
#     Explore About categorical Variables
#     Finding Relationship between features
#
#
# ```
# # This is formatted as code
# ```

# %%
df.shape
# Out:
# (1584, 37)

# %%
df.isnull().sum()
# Out:
# nose_x         0
# nose_y         0
# neck_x         0
# neck_y         0
# Rshoulder_x    0
# Rshoulder_y    0
# Relbow_x       0
# Relbow_y       0
# Rwrist_x       0
# RWrist_y       1
# LShoulder_x    1
# LShoulder_y    1
# LElbow_x       1
# LElbow_y       1
# LWrist_x       1
# LWrist_y       1
# RHip_x         1
# RHip_y         1
# RKnee_x        1
# RKnee_y        1
# RAnkle_x       1
# RAnkle_y       1
# LHip_x         1
# LHip_y         1
# LKnee_x        1
# LKnee_y        1
# LAnkle_x       1
# LAnkle_y       1
# REye_x         1
# REye_y         1
# LEye_x         1
# LEye_y         1
# REar_x         1
# REar_y         1
# LEar_x         1
# LEar_y         1
# class          1
# dtype: int64

# %%
## Focus on replacing missing values
df['RWrist_y'].unique()
# Out:
# array([0.43478261, 0.42934783, 0.42391304, 0.41847826, 0.4076087 ,
#        0.39130435, 0.40217391, 0.41304348, 0.44021739, 0.45652174,
#        0.46195652, 0.35869565, 0.39673913, 0.375     , 0.47826087,
#        0.4673913 , 0.47282609, 0.44565217, 0.45108696, 0.48369565,
#        0.48913043, 0.49456522, 0.5       , 0.36413043, 0.36956522,
#        0.38043478, 0.38586957, 0.33695652, 0.53804348, 0.5326087 ,
#        0.52717391, 0.54347826, 0.55434783, 0.54891304, 0.61413043,
#        0.61956522, 0.60869565, 0.59782609, 0.58152174, 0.5923913 ,
#        0.58695652, 0.57065217, 0.60326087, 0.625     , 0.63043478,
#        0.57608696, 0.55978261, 0.64130435, 0.63586957, 0.56521739,
#        0.50543478, 0.51086957, 0.52173913, 0.51630435, 0.19565217,
#        0.19021739, 0.20108696, 0.20652174, 0.22282609, 0.2173913 ,
#        0.21195652, 0.22826087, 0.23369565, 0.23913043, 0.24456522,
#        0.25543478, 0.25      , 0.26630435, 0.2826087 , 0.28804348,
# ...

# %%
df['RWrist_y'].value_counts()
# Out:
# 0.228261    69
# 0.222826    44
# 0.451087    39
# 0.217391    38
# 0.543478    36
#             ..
# 0.358696     1
# 0.342391     1
# 0.255435     1
# 0.820652     1
# 0.266304     1
# Name: RWrist_y, Length: 111, dtype: int64

# %%
df['RWrist_y'].mode()[0]
# Out:
# 0.2282608695652173

# %%
## Replace the missing values with mode
df['RWrist_y']=df['RWrist_y'].fillna(df['RWrist_y'].mode()[0])

# %%
df['RWrist_y'].isnull().sum()
# Out:
# 0

# %%
df['LShoulder_x'].unique()

# %%
df['LShoulder_x'].value_counts()

# %%
df['LShoulder_x'].mode()[0]
# Out:
# 0.6342592592592593

# %%
df['LShoulder_x']=df['LShoulder_x'].fillna(df['LShoulder_x'].mode()[0])

# %%
df['LShoulder_x'].isnull().sum()

# %%
df['LShoulder_y'].unique()

# %%
df['LShoulder_y'].value_counts()

# %%
df['LShoulder_y'].mode()[0]

# %%
df['LShoulder_y']=df['LShoulder_y'].fillna(df['LShoulder_y'].mode()[0])

# %%
df['LShoulder_y'].isnull().sum()

# %%
df['LElbow_x'].unique()

# %%
df['LElbow_x'].value_counts()

# %%
df['LElbow_x'].mode()[0]

# %%
df['LElbow_x']=df['LElbow_x'].fillna(df['LElbow_x'].mode()[0])

# %%
df['LElbow_x'].isnull().sum()

# %%
df['LElbow_y'].unique()

# %%
df['LElbow_y'].value_counts()

# %%
df['LElbow_y'].mode()[0]

# %%
df['LElbow_y']=df['LElbow_y'].fillna(df['LElbow_y'].mode()[0])

# %%
df['LElbow_y'].isnull().sum()

# %%
df['LWrist_x'].unique()

# %%
df['LWrist_x'].value_counts()

# %%
df['LWrist_x'].mode()[0]

# %%
df['LWrist_x']=df['LWrist_x'].fillna(df['LWrist_x'].mode()[0])

# %%
df['LWrist_x'].isnull().sum()

# %%
df['LWrist_y'].unique()

# %%
df['LWrist_y'].value_counts()

# %%
df['LWrist_y'].mode()[0]

# %%
df['LWrist_y']=df['LWrist_y'].fillna(df['LWrist_y'].mode()[0])

# %%
df['LWrist_y'].isnull().sum()

# %%
df['RHip_x'].unique()

# %%
df['RHip_x'].value_counts()

# %%
df['RHip_x'].mode()[0]

# %%
df['RHip_x']=df['RHip_x'].fillna(df['RHip_x'].mode()[0])

# %%
df['RHip_x'].isnull().sum()

# %%
df['RHip_y'].unique()

# %%
df['RHip_y'].value_counts()

# %%
df['RHip_y'].mode()[0]

# %%
df['RHip_y']=df['RHip_y'].fillna(df['RHip_y'].mode()[0])

# %%
df['RHip_y'].isnull().sum()

# %%
df['RKnee_x'].unique()

# %%
df['RKnee_x'].value_counts()

# %%
df['RKnee_x'].mode()[0]

# %%
df['RKnee_x']=df['RKnee_x'].fillna(df['RKnee_x'].mode()[0])

# %%
df['RKnee_x'].isnull().sum()

# %%
df['RKnee_y'].unique()

# %%
df['RKnee_y'].value_counts()

# %%
df['RKnee_y'].mode()[0]

# %%
df['RKnee_y']=df['RKnee_y'].fillna(df['RKnee_y'].mode()[0])

# %%
df['RKnee_y'].isnull().sum()

# %%
df['RAnkle_x'].unique()

# %%
df['RAnkle_x'].value_counts()

# %%
df['RAnkle_x'].mode()[0]

# %%
df['RAnkle_x']=df['RAnkle_x'].fillna(df['RAnkle_x'].mode()[0])

# %%
df['RAnkle_x'].isnull().sum()

# %%
df['RAnkle_y'].unique()

# %%
df['RAnkle_y'].value_counts()

# %%
df['RAnkle_y'].mode()[0]

# %%
df['RAnkle_y']=df['RAnkle_y'].fillna(df['RAnkle_y'].mode()[0])

# %%
df['RAnkle_y'].isnull().sum()

# %%
df['LHip_x'].unique()

# %%
df['LHip_x'].value_counts()

# %%
df['LHip_x'].mode()[0]

# %%
df['LHip_x']=df['LHip_x'].fillna(df['LHip_x'].mode()[0])

# %%
df['LHip_x'].isnull().sum()

# %%
df['LHip_y'].unique()

# %%
df['LHip_y'].value_counts()

# %%
df['LHip_y'].mode()[0]

# %%
df['LHip_y']=df['LHip_y'].fillna(df['LHip_y'].mode()[0])

# %%
df['LHip_y'].isnull().sum()

# %%
df['LKnee_x'].unique()

# %%
df['LKnee_x'].value_counts()

# %%
df['LKnee_x'].mode()[0]

# %%
df['LKnee_x']=df['LKnee_x'].fillna(df['LKnee_x'].mode()[0])

# %%
df['LKnee_x'].isnull().sum()

# %%
df['LKnee_y'].unique()

# %%
df['LKnee_y'].value_counts()

# %%
df['LKnee_y'].mode()[0]

# %%
df['LKnee_y']=df['LKnee_y'].fillna(df['LKnee_y'].mode()[0])

# %%
df['LKnee_y'].isnull().sum()

# %%
df.isnull().sum()

# %%
df['LAnkle_x'].unique()

# %%
df['LAnkle_x'].value_counts()

# %%
df['LAnkle_x'].mode()[0]

# %%
df['LAnkle_x']=df['LAnkle_x'].fillna(df['LAnkle_x'].mode()[0])

# %%
df['LAnkle_x'].isnull().sum()

# %%
df['LAnkle_y'].unique()

# %%
df['LAnkle_y'].value_counts()

# %%
df['LAnkle_y'].mode()[0]

# %%
df['LAnkle_y']=df['LAnkle_y'].fillna(df['LAnkle_y'].mode()[0])

# %%
df['LAnkle_y'].isnull().sum()

# %%
df['REye_x'].unique()

# %%
df['REye_x'].value_counts()

# %%
df['REye_x'].mode()[0]

# %%
df['REye_x']=df['REye_x'].fillna(df['REye_x'].mode()[0])

# %%
df['REye_x'].isnull().sum()

# %%
df['REye_y'].unique()

# %%
df['REye_y'].value_counts()

# %%
df['REye_y'].mode()[0]

# %%
df['REye_y']=df['REye_y'].fillna(df['REye_y'].mode()[0])

# %%
df['REye_y'].isnull().sum()

# %%
df['LEye_x'].unique()

# %%
df['LEye_x'].value_counts()

# %%
df['LEye_x'].mode()[0]

# %%
df['LEye_x']=df['LEye_x'].fillna(df['LEye_x'].mode()[0])

# %%
df['LEye_x'].isnull().sum()

# %%
df['LEye_y'].unique()

# %%
df['LEye_y'].value_counts()

# %%
df['LEye_y'].mode()[0]

# %%
df['LEye_y']=df['LEye_y'].fillna(df['LEye_y'].mode()[0])

# %%
df['LEye_y'].isnull().sum()

# %%
df['REar_x'].unique()

# %%
df['REar_x'].value_counts()

# %%
df['REar_x'].mode()[0]

# %%
df['REar_x']=df['REar_x'].fillna(df['REar_x'].mode()[0])

# %%
df['REar_x'].isnull().sum()

# %%
df.isnull().sum()

# %%
df['REar_y'].unique()

# %%
df['REar_y'].value_counts()

# %%
df['REar_y'].mode()[0]

# %%
df['REar_y']=df['REar_y'].fillna(df['REar_y'].mode()[0])

# %%
df['REar_y'].isnull().sum()

# %%
df['LEar_x'].unique()

# %%
df['LEar_x'].value_counts()

# %%
df['LEar_x'].mode()[0]

# %%
df['LEar_x']=df['LEar_x'].fillna(df['LEar_x'].mode()[0])

# %%
df['LEar_x'].isnull().sum()

# %%
df['LEar_y'].unique()

# %%
df['LEar_y'].value_counts()

# %%
df['LEar_y'].mode()[0]

# %%
df['LEar_y']=df['LEar_y'].fillna(df['LEar_y'].mode()[0])

# %%
df['LEar_y'].isnull().sum()

# %%
df['class'].unique()

# %%
df['class'].value_counts()

# %%
df['class'].mode()[0]

# %%
df['class']=df['class'].fillna(df['class'].mode()[0])

# %%
df['class'].isnull().sum()

# %%
df.isnull().sum()

# %%
df['class'].value_counts()

# %%
df.shape

# %%
df.info()

# %%
##To check Data Types
df.dtypes

# %%
df.corr()

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
corrmat=df.corr()
top_corr_feature=corrmat.index
plt.figure(figsize=(20,20))
